# %% [markdown]
# # Mac Miller: A lyrical analysis using NLP

# %% [markdown]
# ### Data Extraction

# %%
# setting up libraries
import spotipy
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import gensim
from gensim.models import Word2Vec
import json
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
from lyricsgenius import Genius # lyrics genius is a fantastic library that helps us take lyrics from the Genius API
import nltk
import re
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet

# %%
#setting up Genius API
client_id = 'AqnRTduqC75eC1V8Fr3EKTnLep6I_-rk99_RdWPEpSlfeyg5IoZrLs9KRLQBK6Db'
token = 'r_Gny4srkI6fW0JKR5zYU8LofeURTtx4Up7kQa_kqXlkoy6O82vZ_UaUZTWuq8fg'
genius = Genius(token)

#Removes [chorus] [bridge] etc. tags.
genius.remove_section_headers = True

#excluding repeat songs that might hinder analysis
genius.excluded_terms = ["(Remix)", "(Live)"]
#artist = genius.search_artist("Kendrick Lamar", max_songs=10)

# %% [markdown]
# I had to choose specific albums because analyzing his whole discography might not yield important insights (filler mixtapes or albums that don't portray his personality well). As such, I decided to include his 6 studio albums (Blue Slide Park, Watching Movies with the Sound Off, GO:OD AM, The Divine Feminine, Swimming, and Circles), and five very popular mixtapes (all of which I absolutely love) (K.I.D.S., Best Day Ever, I Love Life Thank You, Macadelic, and Faces).

# %%
# add albums to a list to parse into a dataframe later
albums = []

# The "try/except" block exists because I kept running into a "request timed out" error in the previous 
# code block, so I went and wrote this to retry the call to artist's albums until it works

while True:
    try:
        albums.append(genius.search_album("Blue Slide Park",  "Mac Miller"))
        albums.append(genius.search_album("Watching Movies with the Sound Off",  "Mac Miller"))
        albums.append(genius.search_album("GO:OD AM",  "Mac Miller"))
        albums.append(genius.search_album("The Divine Feminine",  "Mac Miller"))
        albums.append(genius.search_album("Swimming",  "Mac Miller"))
        albums.append(genius.search_album("Circles",  "Mac Miller"))
        albums.append(genius.search_album("K.I.D.S",  "Mac Miller"))
        albums.append(genius.search_album("Best Day Ever",  "Mac Miller"))
        albums.append(genius.search_album("I Love Life, Thank You",  "Mac Miller"))
        albums.append(genius.search_album("Macadelic",  "Mac Miller"))
        albums.append(genius.search_album("Faces",  "Mac Miller"))
        break
    except:
        pass
    
# saving lyrics into files, we keep them separated so we can analyze data by album and not just per song
for i in range(len(albums)):
    albums[i].save_lyrics()
# Out:
# Searching for "Blue Slide Park" by Mac Miller...
# Searching for "Blue Slide Park" by Mac Miller...
# Searching for "Blue Slide Park" by Mac Miller...

# %%
# loading json file as dict
bsp1 = json.load(open("/Users/faisalqureshi/Desktop/Spotify music NLP project/lyrics/Lyrics_BlueSlidePark.json"))
wmtsf1 = json.load(open("/Users/faisalqureshi/Desktop/Spotify music NLP project/lyrics/Lyrics_WatchingMovieswiththeSoundOff.json"))
gam1 = json.load(open("/Users/faisalqureshi/Desktop/Spotify music NLP project/lyrics/Lyrics_GOODAM.json"))
tdf1 = json.load(open("/Users/faisalqureshi/Desktop/Spotify music NLP project/lyrics/Lyrics_TheDivineFeminine.json"))
swim1 = json.load(open("/Users/faisalqureshi/Desktop/Spotify music NLP project/lyrics/Lyrics_Swimming.json"))
circles1 = json.load(open("/Users/faisalqureshi/Desktop/Spotify music NLP project/lyrics/Lyrics_Circles.json"))
kids1 = json.load(open("/Users/faisalqureshi/Desktop/Spotify music NLP project/lyrics/Lyrics_K.I.D.S..json"))
bde1 = json.load(open("/Users/faisalqureshi/Desktop/Spotify music NLP project/lyrics/Lyrics_BestDayEver.json"))
illty1 = json.load(open("/Users/faisalqureshi/Desktop/Spotify music NLP project/lyrics/Lyrics_ILoveLifeThankYou.json"))
mac1 = json.load(open("/Users/faisalqureshi/Desktop/Spotify music NLP project/lyrics/Lyrics_Macadelic.json"))
faces1 = json.load(open("/Users/faisalqureshi/Desktop/Spotify music NLP project/lyrics/Lyrics_Faces.json"))

# normalizing into dataframe and specifying tracks
bsp = pd.json_normalize(bsp1['tracks'])
wmtsf = pd.json_normalize(wmtsf1['tracks'])
gam = pd.json_normalize(gam1["tracks"])
tdf = pd.json_normalize(tdf1['tracks'])
swim = pd.json_normalize(swim1['tracks']).drop("song.stats.concurrents", axis = 1)
circles = pd.json_normalize(circles1['tracks'])
kids = pd.json_normalize(kids1['tracks'])
bde = pd.json_normalize(bde1['tracks'])
illty = pd.json_normalize(illty1['tracks'])
mac = pd.json_normalize(mac1['tracks'])
faces = pd.json_normalize(faces1['tracks']).drop("song.stats.concurrents", axis = 1)

# add all the albums into one list for aggregation
all_albums = [bsp, wmtsf, gam, tdf, swim, circles, kids, bde, illty, mac, faces]

# %% [markdown]
# ### Data Cleaning

# %%
# using regex to remove punctuation and lowercasing lyrics

for i in range(len(all_albums)):
    for j in range(len(all_albums[i][["song.lyrics"]])):
        all_albums[i]["song.lyrics"][j] = all_albums[i]["song.lyrics"][j].replace("\n", ". ").replace("\n\n", '')
        all_albums[i]["song.lyrics"][j] = re.sub("[^a-zA-Z0-9 -]", '', all_albums[i]["song.lyrics"][j]).lower()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
# dropping stop words and lemmatizing the lyrics

lemmatizer = WordNetLemmatizer()
stop_words = nltk.corpus.stopwords.words('english')

# Map POS tag to first character lemmatize() accepts
def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# Funtion to lemmatize words and remove stop words
def lemmatizing_and_stop(lyrics):
    prac = [lemmatizer.lemmatize(lyric, get_wordnet_pos(lyric)) for lyric in nltk.word_tokenize(lyrics)]
    return ' '.join([lyric for lyric in prac if lyric not in (stop_words)])

# Lemmatizing lyrics and removing stop words from them
for i in range(len(all_albums)):
    for j in range(len(all_albums[i][["song.lyrics"]])):
        all_albums[i]["song.lyrics"] = all_albums[i]["song.lyrics"].apply(lambda lyric: lemmatizing_and_stop(lyric))

# %%
# finding unique word count and adding it to the dataframe

def finding_number(lyrics):
    number = len(np.unique(lyrics.split(' '))) / len(lyrics.split(' '))
    return number

for i in range(len(all_albums)):
    all_albums[i]["unique words %"] = all_albums[i]["song.lyrics"].apply(lambda lyric: finding_number(lyric))
    
faces
# Out:
#     number song._type  song.annotation_count  song.api_path  \
# 0        1       song                     13  /songs/426742
# 1        2       song                     19  /songs/402541
# 2        3       song                     52  /songs/426749
# 3        4       song                     22  /songs/426794
# 4        5       song                     24  /songs/426809
# 5        6       song                     23  /songs/426823
# 6        7       song                     16  /songs/426868
# 7        8       song                      7  /songs/403766
# 8        9       song                     27  /songs/426762
# 9       10       song                     15  /songs/426831
# 10      11       song                     12  /songs/426844
# 11      12       song                     23  /songs/426858
# 12      13       song                     40  /songs/359814
# 13      14       song                     26  /songs/426866
# 14      15       song                      1  /songs/426863
# 15      16       song                     15  /songs/426870
# 16      17       song                     10  /songs/426867
# 17      18       song                     24  /songs/402505
# 18      19       song                     17  /songs/426850
# 19      20       song                     18  /songs/426828
# 20      21       song                     21  /songs/426825
# 21      22       song                      7  /songs/426822
# 22      23       song                     50  /songs/426771
# 23      24       song                     28  /songs/426768
#
#                           song.artist_names  \
# 0                                Mac Miller
# 1                                Mac Miller
# 2              Mac Miller (Ft. ScHoolboy Q)
# 3                                Mac Miller
# 4                                Mac Miller
# 5        Mac Miller (Ft. Sir Michael Rocks)
# 6                                Mac Miller
# 7                                Mac Miller
# 8          Mac Miller (Ft. Earl Sweatshirt)
# 9                                Mac Miller
# 10                               Mac Miller
# 11                               Mac Miller
# 12                               Mac Miller
# 13                               Mac Miller
# 14                               Mac Miller
# 15                               Mac Miller
# 16                               Mac Miller
# 17               Mac Miller (Ft. Rick Ross)
# 18              Mac Miller (Ft. Mike Jones)
# 19           Mac Miller (Ft. Vince Staples)
# 20                               Mac Miller
# 21                               Mac Miller
# 10  https://images.genius.com/6476e95bec5c6ed1b91e...   426844
# 11  https://images.genius.com/6476e95bec5c6ed1b91e...   426858
# 12  https://images.genius.com/6a18da086fd33747a37d...   359814
# 13  https://images.genius.com/6476e95bec5c6ed1b91e...   426866
# 14  https://images.genius.com/6476e95bec5c6ed1b91e...   426863
# 15  https://images.genius.com/6476e95bec5c6ed1b91e...   426870
# 16  https://images.genius.com/6476e95bec5c6ed1b91e...   426867
# 17  https://images.genius.com/6476e95bec5c6ed1b91e...   402505
# 18  https://images.genius.com/6476e95bec5c6ed1b91e...   426850
# 19  https://images.genius.com/6476e95bec5c6ed1b91e...   426828
# 20  https://images.genius.com/6476e95bec5c6ed1b91e...   426825
# 21  https://images.genius.com/6476e95bec5c6ed1b91e...   426822
# 22  https://images.genius.com/6476e95bec5c6ed1b91e...   426771
# 23  https://images.genius.com/6476e95bec5c6ed1b91e...   426768
#
#     song.instrumental  ...  song.primary_artist.is_meme_verified  \
# 0               False  ...                                  True
# 1               False  ...                                  True
# 2               False  ...                                  True
# 3               False  ...                                  True
# 4               False  ...                                  True
# 5               False  ...                                  True
# 6               False  ...                                  True
# 7               False  ...                                  True
# 8               False  ...                                  True
# 9               False  ...                                  True
# 10              False  ...                                  True
# 11              False  ...                                  True
# 12              False  ...                                  True
# 13              False  ...                                  True
# 14               True  ...                                  True
# 15              False  ...                                  True
# 16              False  ...                                  True
# 17              False  ...                                  True
# 18              False  ...                                  True
# 19              False  ...                                  True
# 20              False  ...                                  True
# 21              False  ...                                  True
# 22              False  ...                                  True
# 23              False  ...                                  True
#
#    song.primary_artist.is_verified  song.primary_artist.name  \
# 0                             True                Mac Miller
# 1                             True                Mac Miller
# 2                             True                Mac Miller
# 3                             True                Mac Miller
# 4                             True                Mac Miller
# 5                             True                Mac Miller
# 6                             True                Mac Miller
# 7                             True                Mac Miller
# 8                             True                Mac Miller
# 9                             True                Mac Miller
# 10                            True                Mac Miller
# 11                            True                Mac Miller
# 12                            True                Mac Miller
# 13                            True                Mac Miller
# 14                            True                Mac Miller
# 15                            True                Mac Miller
# 16                            True                Mac Miller
# 17                            True                Mac Miller
# 18                            True                Mac Miller
# 19                            True                Mac Miller
# 20                            True                Mac Miller
# 21                            True                Mac Miller
# 22                            True                Mac Miller
# 23                            True                Mac Miller
#
#    song.primary_artist.slug                song.primary_artist.url  \
# 0                Mac-miller  https://genius.com/artists/Mac-miller
# 1                Mac-miller  https://genius.com/artists/Mac-miller
# 2                Mac-miller  https://genius.com/artists/Mac-miller
# 3                Mac-miller  https://genius.com/artists/Mac-miller
# 4                Mac-miller  https://genius.com/artists/Mac-miller
# 5                Mac-miller  https://genius.com/artists/Mac-miller
# 6                Mac-miller  https://genius.com/artists/Mac-miller
# 7                Mac-miller  https://genius.com/artists/Mac-miller
# 8                Mac-miller  https://genius.com/artists/Mac-miller
# 9                Mac-miller  https://genius.com/artists/Mac-miller
# 10               Mac-miller  https://genius.com/artists/Mac-miller
# 11               Mac-miller  https://genius.com/artists/Mac-miller
# 12               Mac-miller  https://genius.com/artists/Mac-miller
# 13               Mac-miller  https://genius.com/artists/Mac-miller
# 14               Mac-miller  https://genius.com/artists/Mac-miller
# 15               Mac-miller  https://genius.com/artists/Mac-miller
# 16               Mac-miller  https://genius.com/artists/Mac-miller
# 17               Mac-miller  https://genius.com/artists/Mac-miller
# 18               Mac-miller  https://genius.com/artists/Mac-miller
# 19               Mac-miller  https://genius.com/artists/Mac-miller
# 20               Mac-miller  https://genius.com/artists/Mac-miller
# 21               Mac-miller  https://genius.com/artists/Mac-miller
# 22               Mac-miller  https://genius.com/artists/Mac-miller
# 23               Mac-miller  https://genius.com/artists/Mac-miller
#
#    song.primary_artist.iq song.artist  \
# 0                   41018  Mac Miller
# 1                   41018  Mac Miller
# 2                   41018  Mac Miller
# 3                   41018  Mac Miller
# 4                   41018  Mac Miller
# 5                   41018  Mac Miller
# 6                   41018  Mac Miller
# 7                   41018  Mac Miller
# 8                   41018  Mac Miller
# 9                   41018  Mac Miller
# 10                  41018  Mac Miller
# 11                  41018  Mac Miller
# 12                  41018  Mac Miller
# 13                  41018  Mac Miller
# 14                  41018  Mac Miller
# 15                  41018  Mac Miller
# 16                  41018  Mac Miller
# 17                  41018  Mac Miller
# 18                  41018  Mac Miller
# 19                  41018  Mac Miller
# 20                  41018  Mac Miller
# 21                  41018  Mac Miller
# 22                  41018  Mac Miller
# 23                  41018  Mac Miller
#
#                                           song.lyrics  unique words  \
# 0   inside outside lyric yeah yeah shoulda die alr...            73
# 1   go lyric without fear face enemy brave upright...           161
# 2   friend lyric one two three pop pop one two thr...           374
# 3   angel dust lyric yeah yeah um uh lady gentlema...           169
# 4   malibu lyric good time trap oh yeah ha-ha-ha o...           188
# 5   lyric tambourine shaker man think im eric andr...           215
# 6   doesnt matter lyric theyve get best equipment ...           207
# 7   therapy lyric pittsburgh man hows feel tell fe...           148
# 8   polo jean lyric yeah fuck go nut give fuck go ...           234
# 9   happy birthday lyric bum-ba-da-bum-bum yeah ye...           153
# 10  wedding lyric ah ah fuck good baby well man ah...           160
# 11  funeral lyric yeah yeah turn headphone yeah ye...           162
# 12  diablo lyric yeah yeah yeah rap diablo yeah ye...           198
# 13  ave maria lyric yeah cant feel leg im parapleg...           183
# 14                                                                1
# 15  san francisco lyric yeah welcome dark side biz...           143
# 16  color shape lyric answer question mm-hmm well ...           117
# 17  insomniak lyric yeah ayy jerm jerm yeah ah ah ...           225
# 18  uber lyric yeah yeah yeah yeah yeah um put spi...           177
# 19  rain lyric take time talkin nigga dont waste n...           178
# 20  apparition lyric yeah yeah gnillor peek tsuj l...           164
# 21  thumbalina lyric straight wan na say one time ...           144
# 22  new face v2 lyric yeah mane know im smokin beg...           335
# 23  grand finale lyric yeah yeah yeah little loude...           159
#
#     unique words %
# 0         0.489933
# 1         0.752336
# 2         0.523077
# 3         0.655039
# 4         0.652778
# 5         0.711921
# 6         0.699324
# 7         0.395722
# 8         0.680233
# 9         0.554348
# 10        0.615385
# 11        0.568421
# 12        0.647059
# 13        0.644366
# 14        1.000000
# 15        0.605932
# 16        0.764706
# 17        0.502232
# 18        0.536364
# 19        0.791111
# 20        0.836735
# 21        0.620690
# 22        0.632075
# 23        0.703540
#
# [24 rows x 40 columns]

# %%
# selecting only the important columns for analysis and removing songs with only instrumentals

for i in range(len(all_albums)):
    # no mac miller song has all unique words except for the ones with no lyrics in them, hence they would have
    # unique words % as 1.
    all_albums[i] = all_albums[i][all_albums[i]["unique words %"] != 1]
    all_albums[i] = all_albums[i][["song.full_title", "song.artist_names", "song.lyrics", "unique words %"]]
